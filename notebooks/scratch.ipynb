# %%
import os
os.chdir("..")

import json
import pandas as pd

from pks.src.i18n import translate_series, translate_string

# %%
dict_df = pd.read_json("i18n/dict.jsonl", lines=True).groupby("index").first()
dict_df

# %%
raw = pd.read_parquet("data/processed/pks.parquet")
raw

# %%
raw.label = translate_series(raw.label, "en")
